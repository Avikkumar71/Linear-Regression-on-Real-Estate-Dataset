# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import fetch_california_housing

# %%
dataset = pd.read_csv('/content/Real estate.csv')

# %%
dataset
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
dataset.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
X = dataset[['X1 transaction date','X2 house age','X3 distance to the nearest MRT station','X4 number of convenience stores','X5 latitude','X6 longitude','Y house price of unit area']]

# %%
Y = dataset['No']

# %%
X
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ...

# %%
Y
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 409    410
# 410    411
# 411    412
# 412    413
# 413    414
# Name: No, Length: 414, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=75)

# %%
X_train
# Out:
#      X1 transaction date  X2 house age  \
# 132             2013.167          26.6
# 209             2012.833          34.8
# 280             2013.250           2.3
# 40              2013.000          13.6
# 340             2013.333          33.6
# ..                   ...           ...
# 26              2012.667           3.1
# 136             2012.750          11.4
# 19              2012.667           1.5
# 368             2013.417          18.2
# 248             2013.000          19.0
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 132                               482.75810                                5
# 209                               175.62940                                8
# 280                               184.33020                                6
# 40                               4082.01500                                0
# 340                               270.88950                                0
# ...

# %%
X_test
# Out:
#      X1 transaction date  X2 house age  \
# 381             2013.417           8.0
# 322             2013.000          12.9
# 262             2012.917          15.9
# 73              2013.167          13.8
# 137             2013.500          13.6
# ..                   ...           ...
# 295             2013.167          18.2
# 82              2013.083          13.2
# 341             2013.000          13.0
# 384             2012.750          16.1
# 387             2013.250          16.2
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 381                                132.5469                                9
# 322                                187.4823                                1
# 262                                289.3248                                5
# 73                                4082.0150                                0
# 137                                319.0708                                6
# ...

# %%
Y_train
# Out:
# 132    133
# 209    210
# 280    281
# 40      41
# 340    341
#       ...
# 26      27
# 136    137
# 19      20
# 368    369
# 248    249
# Name: No, Length: 331, dtype: int64

# %%
Y_test
# Out:
# 381    382
# 322    323
# 262    263
# 73      74
# 137    138
#       ...
# 295    296
# 82      83
# 341    342
# 384    385
# 387    388
# Name: No, Length: 83, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
predictions = lm.predict(X_test)

# %%
predictions
# Out:
# array([206.5088185 , 228.82402437, 196.1783931 , 208.89324549,
#        210.74634384, 200.41754591, 194.91036035, 213.76088828,
#        239.45321668, 207.10205157, 201.76369482, 180.68395374,
#        211.26428297, 210.21730323, 190.9525407 , 215.29813598,
#        207.47680709, 208.66426866, 207.52432986, 207.60923712,
#        203.38992568, 194.44161813, 205.11654735, 214.20011462,
#        196.94334547, 200.72772542, 216.63678653, 193.10861016,
#        205.80666621, 181.9495038 , 212.08072449, 218.74171774,
#        196.91468865, 221.1010319 , 199.6789136 , 224.9153248 ,
#        223.43245734, 202.03608377, 200.86991047, 198.00178699,
#        203.2516772 , 215.23901602, 206.7661292 , 194.95790739,
#        192.86463176, 202.18778506, 208.55161786, 203.9319749 ,
#        197.12414344, 225.50647979, 211.90496077, 205.46892171,
#        202.95364353, 204.2230638 , 210.78580104, 185.43199041,
#        233.19101157, 199.80081525, 199.2136775 , 206.35773922,
# ...

# %%
Y_test
# Out:
# 381    382
# 322    323
# 262    263
# 73      74
# 137    138
#       ...
# 295    296
# 82      83
# 341    342
# 384    385
# 387    388
# Name: No, Length: 83, dtype: int64

# %%
from sklearn import metrics

# %%
print('MAE: ',metrics.mean_absolute_error(Y_test, predictions))
# Out:
# MAE:  100.17066300820197

# %%
print('MSE: ',metrics.mean_squared_error(Y_test, predictions))
# Out:
# MSE:  13818.872695546861

# %%
print('RMSE: ',np.sqrt(metrics.mean_squared_error(Y_test, predictions)))
# Out:
# RMSE:  117.55370132644425

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
df = dataset.drop(columns = [ ])

# %%
df1 = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
df1
# Out:
#            No  X1 transaction date  X2 house age  \
# 0    0.000000             0.272926      0.730594
# 1    0.002421             0.272926      0.445205
# 2    0.004843             1.000000      0.303653
# 3    0.007264             0.909389      0.303653
# 4    0.009685             0.181223      0.114155
# ..        ...                  ...           ...
# 409  0.990315             0.363537      0.312785
# 410  0.992736             0.000000      0.127854
# 411  0.995157             0.636463      0.429224
# 412  0.997579             0.363537      0.184932
# 413  1.000000             0.909389      0.148402
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  0.009513                              1.0
# 1                                  0.043809                              0.9
# 2                                  0.083315                              0.5
# ...

# %%
x1=df1[['X1 transaction date','X2 house age','X3 distance to the nearest MRT station','X4 number of convenience stores','X5 latitude','X6 longitude','Y house price of unit area']]

# %%
y1 = df1['No']

# %%
x1
# Out:
#      X1 transaction date  X2 house age  \
# 0               0.272926      0.730594
# 1               0.272926      0.445205
# 2               1.000000      0.303653
# 3               0.909389      0.303653
# 4               0.181223      0.114155
# ..                   ...           ...
# 409             0.363537      0.312785
# 410             0.000000      0.127854
# 411             0.636463      0.429224
# 412             0.363537      0.184932
# 413             0.909389      0.148402
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  0.009513                              1.0
# 1                                  0.043809                              0.9
# 2                                  0.083315                              0.5
# 3                                  0.083315                              0.5
# 4                                  0.056799                              0.5
# ...

# %%
y1
# Out:
# 0      0.000000
# 1      0.002421
# 2      0.004843
# 3      0.007264
# 4      0.009685
#          ...
# 409    0.990315
# 410    0.992736
# 411    0.995157
# 412    0.997579
# 413    1.000000
# Name: No, Length: 414, dtype: float64

# %%
x1_train, x1_test, y1_train, y1_test = train_test_split(x1, y1, test_size=0.2, random_state=75)

# %%
x1_train
# Out:
#      X1 transaction date  X2 house age  \
# 132             0.545852      0.607306
# 209             0.181223      0.794521
# 280             0.636463      0.052511
# 40              0.363537      0.310502
# 340             0.727074      0.767123
# ..                   ...           ...
# 26              0.000000      0.070776
# 136             0.090611      0.260274
# 19              0.000000      0.034247
# 368             0.818777      0.415525
# 248             0.363537      0.433790
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 132                                0.071060                              0.5
# 209                                0.023551                              0.8
# 280                                0.024897                              0.6
# 40                                 0.627820                              0.0
# 340                                0.038286                              0.0
# ...

# %%
y1_train
# Out:
# 132    0.319613
# 209    0.506053
# 280    0.677966
# 40     0.096852
# 340    0.823245
#          ...
# 26     0.062954
# 136    0.329298
# 19     0.046005
# 368    0.891041
# 248    0.600484
# Name: No, Length: 331, dtype: float64

# %%
x1_test
# Out:
#      X1 transaction date  X2 house age  \
# 381             0.818777      0.182648
# 322             0.363537      0.294521
# 262             0.272926      0.363014
# 73              0.545852      0.315068
# 137             0.909389      0.310502
# ..                   ...           ...
# 295             0.545852      0.415525
# 82              0.454148      0.301370
# 341             0.363537      0.296804
# 384             0.090611      0.367580
# 387             0.636463      0.369863
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 381                                0.016886                              0.9
# 322                                0.025384                              0.1
# 262                                0.041138                              0.5
# 73                                 0.627820                              0.0
# 137                                0.045739                              0.6
# ...

# %%
y1_test
# Out:
# 381    0.922518
# 322    0.779661
# 262    0.634383
# 73     0.176755
# 137    0.331719
#          ...
# 295    0.714286
# 82     0.198547
# 341    0.825666
# 384    0.929782
# 387    0.937046
# Name: No, Length: 83, dtype: float64

# %%
lm.fit(x1_train,y1_train)
# Out:
# LinearRegression()

# %%
pred = lm.predict(x1_test)

# %%
pred
# Out:
# array([0.49760004, 0.55163202, 0.47258691, 0.50337348, 0.5078604 ,
#        0.4828512 , 0.46951661, 0.51515954, 0.57736856, 0.49903644,
#        0.48611064, 0.43507011, 0.50911449, 0.50657943, 0.45993351,
#        0.51888169, 0.49994384, 0.50281905, 0.50005891, 0.5002645 ,
#        0.49004825, 0.46838164, 0.49422893, 0.51622304, 0.47443909,
#        0.48360224, 0.52212297, 0.46515402, 0.49589992, 0.43813439,
#        0.51109134, 0.52721966, 0.47436971, 0.53293228, 0.48106274,
#        0.54216786, 0.53857738, 0.48677018, 0.48394651, 0.47700191,
#        0.4897135 , 0.51873854, 0.49822307, 0.46963174, 0.46456327,
#        0.48713749, 0.50254629, 0.49136071, 0.47487686, 0.54359922,
#        0.51066576, 0.49508213, 0.48899187, 0.49206553, 0.50795593,
#        0.44656656, 0.56220584, 0.48135791, 0.47993627, 0.49723424,
#        0.49141984, 0.51800337, 0.49111602, 0.49600846, 0.55412371,
#        0.47416983, 0.49905453, 0.5086639 , 0.4905381 , 0.47710521,
# ...

# %%
print('MAE: ',metrics.mean_absolute_error(y1_test, pred))
# Out:
# MAE:  0.2425439782280912

# %%
print('MSE: ',metrics.mean_squared_error(y1_test, pred))
# Out:
# MSE:  0.08101632005550112

# %%
print('RMSE: ',np.sqrt(metrics.mean_squared_error(y1_test, pred)))
# Out:
# RMSE:  0.2846336593860626
